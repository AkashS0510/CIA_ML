# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
coords = np.random.randn(1000, 2)

# %%
df=pd.DataFrame(coords)
df
# Out:
#             0         1
# 0    1.764052  0.400157
# 1    0.978738  2.240893
# 2    1.867558 -0.977278
# 3    0.950088 -0.151357
# 4   -0.103219  0.410599
# ..        ...       ...
# 995  1.342622 -0.739936
# 996  1.315138 -0.323457
# 997  0.197828  0.097751
# 998  1.401523  0.158434
# 999 -1.141901 -1.310970
#
# [1000 rows x 2 columns]

# %%
x=df[0]
y=df[1]

# %%
plt.scatter(x,y)

# %%
np.random.seed(0)
slope=np.random.rand()
intercept=np.random.rand()

print(slope)
print(intercept)
# Out:
# 0.5488135039273248
# 0.7151893663724195

# %%
y_pred=slope*x+intercept

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
def cost(y,y_pred):
    c= np.sum((y-y_pred)**2)/(len(y))
    return c

# %%
cost(y,y_pred)
# Out:
# 1.7729917016331818

# %%
#to update weights:

def update_weights(slope,intercept):
    s=slope-(0.01*(cost(y,y_pred)))
    c=intercept-(0.01*(cost(y,y_pred)))
    return s,c

# %%
##Gradient Descent

costt=cost(y_pred,y)
l=[]
# print(costt)
for i in range(100):
    slope,intercept=update_weights(slope,intercept)
    y_pred=slope*x+intercept
    
    if costt<cost(y_pred,y):
        break
    costt=cost(y_pred,y)
    l.append(costt)
    print("Cost : ",cost(y_pred,y))
    plt.scatter(x,y)
    plt.plot(x,y_pred,c='r')
    plt.show()
# Out:
# Cost :  1.7299030301872222
# Cost :  1.6890167652587473
# Cost :  1.6501977346076873
# Cost :  1.6133214001671947
# Cost :  1.5782728803865034
# Cost :  1.5449460766281
# Cost :  1.513242891156266
# Cost :  1.4830725259125603
# Cost :  1.4543508526904716
# Cost :  1.426999846534482
# Cost :  1.4009470752300153
# Cost :  1.3761252386465466
# Cost :  1.3524717524686602
# Cost :  1.329928371517438
# Cost :  1.3084408484427812
# Cost :  1.2879586240690817
# Cost :  1.2684345461130848
# Cost :  1.2498246133730555
# Cost :  1.2320877428203798
# Cost :  1.2151855573151296
# Cost :  1.1990821919215977
# Cost :  1.1837441170232352
# Cost :  1.1691399766328576
# Cost :  1.1552404404670853
# Cost :  1.1420180685066847
# Cost :  1.1294471868994884
# Cost :  1.1175037741820524
# Cost :  1.10616535690223
# Cost :  1.0954109138189303
# Cost :  1.0852207879391058
# Cost :  1.0755766057266187
# Cost :  1.066461202884234
# Cost :  1.0578585561695257
# Cost :  1.0497537207587893
# ...

# %%
plt.plot(l)
plt.title('Gradient Descent Curve');

# %%
print("Cost: ",cost(y_pred,y))
plt.scatter(x,y)
plt.plot(x,y_pred,c='r')
plt.title("Best Fit Line");
# Out:
# Cost:  0.9771777897882445

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
x=np.array(x)
x=x.reshape(-1,1)
lr.fit(x,y)
Y_PRED=lr.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,Y_PRED,c='r')
plt.title("Best Fit Line");

# %%
print("Loss(MSE) using Gradient Descent", cost(y,y_pred))
print("Loss(MSE) using SKlearn", cost(y,Y_PRED))
# Out:
# Loss(MSE) using Gradient Descent 0.9771777897882445
# Loss(MSE) using SKlearn 0.9636177983408709

# %% [markdown]
# # INFERENCES:

# %% [markdown]
# The cost in Gradient Descent Minimizes after nearly 50 iterations.
# There is a slight error difference between the mse using GD and Sklearn.
# There is a slight differences in the best fit line due to the slight error in the cost function.
